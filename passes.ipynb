# %% [markdown]
# <center>
#
# # Football Analytics

# %% [markdown]
# Neste notebook iremos explorar dados gratuitos disponibilizados pelo StatsBomb.

# %% [markdown]
# ## IMPORTANDO AS BIBLIOTECAS NECESSÁRIAS

# %%
# Importando Bibliotecas necessárias
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import to_rgba
from urllib.request import urlopen
from mplsoccer import Sbopen, Pitch, FontManager, VerticalPitch, add_image
from PIL import Image
from statsbombpy import sb

# %%
# Ajustar as configurações de exibição do pandas
pd.set_option('display.max_columns', None)  # None permite mostrar todas as colunas

# %% [markdown]
# ## EXTRAINDO AS COMPETIÇÕES E TEMPORADAS DISPONÍVEIS

# %%
competitions = sb.competitions()
competitions.head(3)
# Out:
#    competition_id  season_id country_name        competition_name  \
# 0               9        281      Germany           1. Bundesliga
# 1               9         27      Germany           1. Bundesliga
# 2            1267        107       Africa  African Cup of Nations
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                       True
#
#   season_name               match_updated           match_updated_360  \
# 0   2023/2024  2024-07-15T14:15:54.671676  2024-07-15T14:17:00.877356
# 1   2015/2016  2024-05-19T11:11:14.192381                        None
# 2        2023  2024-06-13T07:51:02.452825                        None
#
#           match_available_360             match_available
# 0  2024-07-15T14:17:00.877356  2024-07-15T14:15:54.671676
# 1                        None  2024-05-19T11:11:14.192381
# 2                        None  2024-06-13T07:51:02.452825

# %%
# Criando uma lista com todas competições e seus respectivos ids, ordenadas de forma alfabética
competitions_list = competitions[['competition_name', 'competition_id']].drop_duplicates().reset_index(drop=True)

competitions_list
# Out:
#            competition_name  competition_id
# 0             1. Bundesliga               9
# 1    African Cup of Nations            1267
# 2          Champions League              16
# 3              Copa America             223
# 4              Copa del Rey              87
# 5   FA Women's Super League              37
# 6        FIFA U20 World Cup            1470
# 7            FIFA World Cup              43
# 8       Indian Super league            1238
# 9                   La Liga              11
# 10         Liga Profesional              81
# 11                  Ligue 1               7
# 12      Major League Soccer              44
# 13    North American League             116
# 14                     NWSL              49
# 15           Premier League               2
# 16                  Serie A              12
# 17                UEFA Euro              55
# 18       UEFA Europa League              35
# 19        UEFA Women's Euro              53
# 20        Women's World Cup              72

# %%
# Criando uma lista com todas as temporadas listadas da mais recente para a mais antiga
seasons_list = competitions[['season_name', 'season_id']].sort_values(by='season_name', ascending=False).drop_duplicates().reset_index(drop=True)

seasons_list
# Out:
#    season_name  season_id
# 0         2024        282
# 1    2023/2024        281
# 2         2023        107
# 3    2022/2023        235
# 4         2022        106
# 5    2021/2022        108
# 6    2020/2021         90
# 7         2020         43
# 8    2019/2020         42
# 9         2019         30
# 10   2018/2019          4
# 11        2018          3
# 12   2017/2018          1
# 13   2016/2017          2
# 14   2015/2016         27
# 15   2014/2015         26
# 16   2013/2014         25
# 17   2012/2013         24
# 18   2011/2012         23
# 19   2010/2011         22
# 20   2009/2010         21
# 21   2008/2009         41
# 22   2007/2008         40
# 23   2006/2007         39
# 24   2005/2006         38
# 25   2004/2005         37
# 26   2003/2004         44
# 27   1999/2000         76
# 28   1997/1998         48
# 29        1990         55
# 30   1988/1989         75
# 31   1986/1987         86
# 32        1986         54
# 33   1983/1984         84
# 34   1982/1983        268
# 35        1981        275
# 36        1979        274
# 37   1977/1978        279
# 38        1977         68
# 39        1974         51
# 40   1973/1974        278
# 41   1972/1973        277
# 42   1971/1972         71
# 43   1970/1971        276
# 44        1970        272
# 45        1962        270
# 46        1958        269

# %% [markdown]
# ## SELECIONANDO COMPETIÇÃO E TEMPORADA

# %%
# Altere o id da competição e da temporada conforme desejar observando as listagens acima
campeonato = sb.matches(competition_id=43, season_id=106)
campeonato.head(3)
# Out:
#    match_id  match_date      kick_off                     competition season  \
# 0   3857256  2022-12-02  21:00:00.000  International - FIFA World Cup   2022
# 1   3869151  2022-12-03  21:00:00.000  International - FIFA World Cup   2022
# 2   3857257  2022-11-30  17:00:00.000  International - FIFA World Cup   2022
#
#    home_team    away_team  home_score  away_score match_status  \
# 0     Serbia  Switzerland           2           3    available
# 1  Argentina    Australia           2           1    available
# 2  Australia      Denmark           1           0    available
#
#   match_status_360                last_updated            last_updated_360  \
# 0        available  2023-02-17T23:45:15.306706  2023-04-26T23:49:58.956186
# 1        available  2023-07-30T07:46:05.382784  2023-07-30T07:48:51.865595
# 2        available  2023-04-28T17:13:10.958725  2023-06-20T11:04:37.638969
#
#    match_week competition_stage                stadium  \
# 0           3       Group Stage            Stadium 974
# 1           4       Round of 16  Ahmad bin Ali Stadium
# 2           3       Group Stage   Al Janoub Stadium
#
#                      referee             home_managers        away_managers  \
# 0  Fernando Andrés Rapallini          Dragan Stojković          Murat Yakin
# 1           Szymon Marciniak  Lionel Sebastián Scaloni  Graham James Arnold
# 2           Mustapha Ghorbal       Graham James Arnold      Kasper Hjulmand
#
#   data_version shot_fidelity_version xy_fidelity_version
# 0        1.1.0                     2                   2
# 1        1.1.0                     2                   2
# 2        1.1.0                     2                   2

# %%
# checando a escrita exata de cada equipe
campeonato['home_team'].sort_values().unique()
# Out:
# array(['Argentina', 'Australia', 'Belgium', 'Brazil', 'Cameroon',
#        'Canada', 'Costa Rica', 'Croatia', 'Denmark', 'Ecuador', 'England',
#        'France', 'Germany', 'Ghana', 'Iran', 'Japan', 'Mexico', 'Morocco',
#        'Netherlands', 'Poland', 'Portugal', 'Qatar', 'Saudi Arabia',
#        'Senegal', 'Serbia', 'South Korea', 'Spain', 'Switzerland',
#        'Tunisia', 'United States', 'Uruguay', 'Wales'], dtype=object)

# %% [markdown]
# ## SELECIONANDO EQUIPE

# %%
# Filtrando partidas de uma seleção específica (Selecione a equipe que desejar)

equipe = 'Brazil'
df_partidas = campeonato.loc[(campeonato['home_team'] == f'{equipe}')|(campeonato['away_team'] == f'{equipe}')]
df_partidas.head(3)
# Out:
#     match_id  match_date      kick_off                     competition season  \
# 3    3857258  2022-11-24  21:00:00.000  International - FIFA World Cup   2022
# 14   3857269  2022-11-28  18:00:00.000  International - FIFA World Cup   2022
# 22   3869420  2022-12-09  17:00:00.000  International - FIFA World Cup   2022
#
#    home_team    away_team  home_score  away_score match_status  \
# 3     Brazil       Serbia           2           0    available
# 14    Brazil  Switzerland           1           0    available
# 22   Croatia       Brazil           1           1    available
#
#    match_status_360                last_updated            last_updated_360  \
# 3         available  2023-06-24T17:17:27.911026  2023-07-11T14:56:31.096588
# 14        available  2023-03-28T12:54:30.503171  2023-07-11T15:07:29.255525
# 22        available  2023-04-19T06:28:33.041249  2023-04-26T23:04:13.569501
#
#     match_week competition_stage                  stadium  \
# 3            1       Group Stage           Lusail Stadium
# 14           2       Group Stage              Stadium 974
# 22           5    Quarter-finals  Education City Stadium
#
#                          referee           home_managers  \
# 3                Alireza Faghani   Telê Santana da Silva
# 14  Ivan Arcides Barton Cisneros  Adenor Leonardo Bacchi
# 22                Michael Oliver            Zlatko Dalić
#
#             away_managers data_version shot_fidelity_version  \
# 3        Dragan Stojković        1.1.0                     2
# 14            Murat Yakin        1.1.0                     2
# 22  Telê Santana da Silva        1.1.0                     2
#
#    xy_fidelity_version
# 3                    2
# 14                   2
# 22                   2

# %%
# Extarindo a lista de jogos da equipe selecionada
jogos_ids = df_partidas['match_id'].unique().tolist()
jogos_ids
# Out:
# [3857258, 3857269, 3869420, 3869253, 3857280]

# %%
# Inicializar o parser
parser = Sbopen()

# Listas para armazenar os dataframes
all_df = []
all_related = []
all_freeze = []
all_tactics = []

# Iterar sobre cada ID de jogo e coletar os dados
for jogo in jogos_ids:
    df, related, freeze, tactics = parser.event(jogo)
    
    # Adicionar os dataframes coletados às listas correspondentes
    all_df.append(df)
    all_related.append(related)
    all_freeze.append(freeze)
    all_tactics.append(tactics)

df_combined = pd.concat(all_df, ignore_index=True) # Informações de eventos detalhados
related_combined = pd.concat(all_related, ignore_index=True) # Informação de eventos relacionados (ex: Pass - Ball Receipt)
freeze_combined = pd.concat(all_freeze, ignore_index=True) # Informações de coordenada dos eventos
tactics_combined = pd.concat(all_tactics, ignore_index=True) # informações dos jogadores(nº camisa, posição, nome e ID)

# %%
# df contendo todos os jogos da equipe selecionada
df_combined.sample(3)
# Out:
#                                          id  index  period        timestamp  \
# 16988  b09497ba-3b03-4e69-893d-e8c90654cf0a    354       1  00:08:14.408000
# 7282   7ddea76c-0ee7-4086-9b28-25f31d8cce2a   3627       2  00:47:11.707000
# 3587   9bb807ae-e489-4386-8a33-b79557387b88   3588       2  00:49:43.203000
#
#        minute  second  possession  duration  match_id  type_id      type_name  \
# 16988       8      14          16  0.000000   3857280        2  Ball Recovery
# 7282       92      11         163  0.884417   3857269       30           Pass
# 3587       94      43         164  0.686545   3857258       30           Pass
#
#        possession_team_id possession_team_name  play_pattern_id  \
# 16988                2722             Cameroon                1
# 7282                  773          Switzerland                4
# 3587                  781               Brazil                4
#
#       play_pattern_name  team_id    team_name tactics_formation  player_id  \
# 16988      Regular Play     2722     Cameroon              None    12623.0
# 7282      From Throw In      773  Switzerland              None     8814.0
# 3587      From Throw In      781       Brazil              None     3295.0
#
#                     player_name  position_id             position_name  \
# 16988       Pierre Kunde Malong          9.0  Right Defensive Midfield
# 7282                Nico Elvedi          5.0          Left Center Back
# 3587   Thiago Emiliano da Silva          5.0          Left Center Back
#
#        pass_recipient_id       pass_recipient_name  pass_length  pass_angle  \
# 16988                NaN                       NaN          NaN         NaN
# 7282             12326.0            Renato Steffen     8.453402   -0.479519
# 3587              5539.0  Carlos Henrique Casimiro    12.124768    0.434136
#
#        pass_height_id pass_height_name  end_x  end_y  body_part_id  \
# 16988             NaN              NaN    NaN    NaN           NaN
# 7282              1.0      Ground Pass   71.1    4.2          40.0
# 3587              1.0      Ground Pass   56.3   42.3          40.0
#
#       body_part_name  sub_type_id sub_type_name     x     y  under_pressure  \
# 16988            NaN          NaN           NaN  75.0  28.7             NaN
# 7282      Right Foot          NaN           NaN  63.6   8.1             NaN
# 3587      Right Foot          NaN           NaN  45.3  37.2             NaN
#
#        counterpress  outcome_id outcome_name  out pass_cross pass_switch  \
# 16988           NaN         NaN          NaN  NaN        NaN         NaN
# 7282            NaN         NaN          NaN  NaN        NaN         NaN
# 3587            NaN         NaN          NaN  NaN        NaN         NaN
#
#        off_camera  foul_committed_card_id foul_committed_card_name aerial_won  \
# 16988         NaN                     NaN                      NaN        NaN
# 7282          NaN                     NaN                      NaN        NaN
# 3587          NaN                     NaN                      NaN        NaN
#
#       foul_committed_advantage foul_won_advantage foul_won_defensive  \
# 16988                      NaN                NaN                NaN
# 7282                       NaN                NaN                NaN
# 3587                       NaN                NaN                NaN
#
#        technique_id technique_name shot_one_on_one  shot_statsbomb_xg  end_z  \
# 16988           NaN            NaN             NaN                NaN    NaN
# 7282            NaN            NaN             NaN                NaN    NaN
# 3587            NaN            NaN             NaN                NaN    NaN
#
#        goalkeeper_position_id goalkeeper_position_name  \
# 16988                     NaN                      NaN
# 7282                      NaN                      NaN
# 3587                      NaN                      NaN
#
#       injury_stoppage_in_chain pass_assisted_shot_id pass_shot_assist  \
# 16988                      NaN                   NaN              NaN
# 7282                       NaN                   NaN              NaN
# 3587                       NaN                   NaN              NaN
#
#       shot_key_pass_id dribble_nutmeg ball_recovery_recovery_failure  \
# 16988              NaN            NaN                            NaN
# 7282               NaN            NaN                            NaN
# 3587               NaN            NaN                            NaN
#
#       dribble_overrun ball_recovery_offensive shot_first_time block_offensive  \
# 16988             NaN                     NaN             NaN             NaN
# 7282              NaN                     NaN             NaN             NaN
# 3587              NaN                     NaN             NaN             NaN
#
#        substitution_replacement_id substitution_replacement_name  \
# 16988                          NaN                           NaN
# 7282                           NaN                           NaN
# 3587                           NaN                           NaN
#
#        bad_behaviour_card_id bad_behaviour_card_name pass_goal_assist  \
# 16988                    NaN                     NaN              NaN
# 7282                     NaN                     NaN              NaN
# 3587                     NaN                     NaN              NaN
#
#       pass_cut_back block_deflection shot_deflected dribble_no_touch  \
# 16988           NaN              NaN            NaN              NaN
# 7282            NaN              NaN            NaN              NaN
# 3587            NaN              NaN            NaN              NaN
#
#       foul_committed_offensive pass_miscommunication pass_deflected  \
# 16988                      NaN                   NaN            NaN
# 7282                       NaN                   NaN            NaN
# 3587                       NaN                   NaN            NaN
#
#       pass_no_touch half_start_late_video_start foul_committed_penalty  \
# 16988           NaN                         NaN                    NaN
# 7282            NaN                         NaN                    NaN
# 3587            NaN                         NaN                    NaN
#
#       foul_won_penalty
# 16988              NaN
# 7282               NaN
# 3587               NaN

# %%
# Extraindo os nomes das ações que podem ser analisadas
df_combined['type_name'].sort_values().unique()
# Out:
# array(['50/50', 'Bad Behaviour', 'Ball Receipt', 'Ball Recovery', 'Block',
#        'Carry', 'Clearance', 'Dispossessed', 'Dribble', 'Dribbled Past',
#        'Duel', 'Error', 'Foul Committed', 'Foul Won', 'Goal Keeper',
#        'Half End', 'Half Start', 'Injury Stoppage', 'Interception',
#        'Miscontrol', 'Offside', 'Pass', 'Player Off', 'Player On',
#        'Pressure', 'Referee Ball-Drop', 'Shield', 'Shot', 'Starting XI',
#        'Substitution', 'Tactical Shift'], dtype=object)

# %%
df_pass = df_combined[df_combined['type_name'] == 'Pass']

df_pass = df_pass[df_pass['team_name'] == equipe]

df_pass.head()
# Out:
#                                       id  index  period        timestamp  \
# 4   dd455069-07ce-4acb-a490-81118fcb0235      5       1  00:00:00.360000
# 7   3ec348c7-e144-4c2a-8ad0-5c6e18199403      8       1  00:00:02.717000
# 10  b3516a13-1244-4c4d-9d27-baf80949053b     11       1  00:00:06.342000
# 13  ab9375d9-2e5b-40e6-8471-5ac9014edb02     14       1  00:00:09.553000
# 16  b83a8468-5a6a-4dd7-ae91-d4785fb3ec64     17       1  00:00:14.612000
#
#     minute  second  possession  duration  match_id  type_id type_name  \
# 4        0       0           2  0.757092   3857258       30      Pass
# 7        0       2           2  1.945839   3857258       30      Pass
# 10       0       6           2  0.912137   3857258       30      Pass
# 13       0       9           2  1.498808   3857258       30      Pass
# 16       0      14           2  1.530032   3857258       30      Pass
#
#     possession_team_id possession_team_name  play_pattern_id  \
# 4                  781               Brazil                9
# 7                  781               Brazil                9
# 10                 781               Brazil                9
# 13                 781               Brazil                9
# 16                 781               Brazil                9
#
#    play_pattern_name  team_id team_name tactics_formation  player_id  \
# 4      From Kick Off      781    Brazil              None     3280.0
# 7      From Kick Off      781    Brazil              None     4320.0
# 10     From Kick Off      781    Brazil              None     6945.0
# 13     From Kick Off      781    Brazil              None     5539.0
# 16     From Kick Off      781    Brazil              None     3295.0
#
#                       player_name  position_id              position_name  \
# 4          Richarlison de Andrade         23.0             Center Forward
# 7   Neymar da Silva Santos Junior         19.0  Center Attacking Midfield
# 10         Alex Sandro Lobo Silva          6.0                  Left Back
# 13       Carlos Henrique Casimiro         11.0    Left Defensive Midfield
# 16       Thiago Emiliano da Silva          5.0           Left Center Back
#
#     pass_recipient_id            pass_recipient_name  pass_length  pass_angle  \
# 4              4320.0  Neymar da Silva Santos Junior     3.313608   -1.661456
# 7              6945.0         Alex Sandro Lobo Silva    24.788708   -2.066923
# 10             5539.0       Carlos Henrique Casimiro    15.370751    1.909006
# 13             3295.0       Thiago Emiliano da Silva     9.616653    2.846152
# 16             6945.0         Alex Sandro Lobo Silva    20.900240   -1.566012
#
#     pass_height_id pass_height_name  end_x  end_y  body_part_id  \
# 4              1.0      Ground Pass   59.7   36.7          40.0
# 7              1.0      Ground Pass   51.4   11.7          40.0
# 10             1.0      Ground Pass   51.6   24.3          38.0
# 13             1.0      Ground Pass   37.6   23.4          40.0
# 16             1.0      Ground Pass   38.7    7.2          40.0
#
#    body_part_name  sub_type_id sub_type_name     x     y  under_pressure  \
# 4      Right Foot         65.0      Kick Off  60.0  40.0             NaN
# 7      Right Foot          NaN           NaN  63.2  33.5             NaN
# 10      Left Foot          NaN           NaN  56.7   9.8             NaN
# 13     Right Foot          NaN           NaN  46.8  20.6             NaN
# 16     Right Foot          NaN           NaN  38.6  28.1             NaN
#
#     counterpress  outcome_id outcome_name  out pass_cross pass_switch  \
# 4            NaN         NaN          NaN  NaN        NaN         NaN
# 7            NaN         NaN          NaN  NaN        NaN         NaN
# 10           NaN         NaN          NaN  NaN        NaN         NaN
# 13           NaN         NaN          NaN  NaN        NaN         NaN
# 16           NaN         NaN          NaN  NaN        NaN         NaN
#
#     off_camera  foul_committed_card_id foul_committed_card_name aerial_won  \
# 4          NaN                     NaN                      NaN        NaN
# 7          NaN                     NaN                      NaN        NaN
# 10         NaN                     NaN                      NaN        NaN
# 13         NaN                     NaN                      NaN        NaN
# 16         NaN                     NaN                      NaN        NaN
#
#    foul_committed_advantage foul_won_advantage foul_won_defensive  \
# 4                       NaN                NaN                NaN
# 7                       NaN                NaN                NaN
# 10                      NaN                NaN                NaN
# 13                      NaN                NaN                NaN
# 16                      NaN                NaN                NaN
#
#     technique_id technique_name shot_one_on_one  shot_statsbomb_xg  end_z  \
# 4            NaN            NaN             NaN                NaN    NaN
# 7            NaN            NaN             NaN                NaN    NaN
# 10           NaN            NaN             NaN                NaN    NaN
# 13           NaN            NaN             NaN                NaN    NaN
# 16           NaN            NaN             NaN                NaN    NaN
#
#     goalkeeper_position_id goalkeeper_position_name injury_stoppage_in_chain  \
# 4                      NaN                      NaN                      NaN
# 7                      NaN                      NaN                      NaN
# 10                     NaN                      NaN                      NaN
# 13                     NaN                      NaN                      NaN
# 16                     NaN                      NaN                      NaN
#
#    pass_assisted_shot_id pass_shot_assist shot_key_pass_id dribble_nutmeg  \
# 4                    NaN              NaN              NaN            NaN
# 7                    NaN              NaN              NaN            NaN
# 10                   NaN              NaN              NaN            NaN
# 13                   NaN              NaN              NaN            NaN
# 16                   NaN              NaN              NaN            NaN
#
#    ball_recovery_recovery_failure dribble_overrun ball_recovery_offensive  \
# 4                             NaN             NaN                     NaN
# 7                             NaN             NaN                     NaN
# 10                            NaN             NaN                     NaN
# 13                            NaN             NaN                     NaN
# 16                            NaN             NaN                     NaN
#
#    shot_first_time block_offensive  substitution_replacement_id  \
# 4              NaN             NaN                          NaN
# 7              NaN             NaN                          NaN
# 10             NaN             NaN                          NaN
# 13             NaN             NaN                          NaN
# 16             NaN             NaN                          NaN
#
#    substitution_replacement_name  bad_behaviour_card_id  \
# 4                            NaN                    NaN
# 7                            NaN                    NaN
# 10                           NaN                    NaN
# 13                           NaN                    NaN
# 16                           NaN                    NaN
#
#    bad_behaviour_card_name pass_goal_assist pass_cut_back block_deflection  \
# 4                      NaN              NaN           NaN              NaN
# 7                      NaN              NaN           NaN              NaN
# 10                     NaN              NaN           NaN              NaN
# 13                     NaN              NaN           NaN              NaN
# 16                     NaN              NaN           NaN              NaN
#
#    shot_deflected dribble_no_touch foul_committed_offensive  \
# 4             NaN              NaN                      NaN
# 7             NaN              NaN                      NaN
# 10            NaN              NaN                      NaN
# 13            NaN              NaN                      NaN
# 16            NaN              NaN                      NaN
#
#    pass_miscommunication pass_deflected pass_no_touch  \
# 4                    NaN            NaN           NaN
# 7                    NaN            NaN           NaN
# 10                   NaN            NaN           NaN
# 13                   NaN            NaN           NaN
# 16                   NaN            NaN           NaN
#
#    half_start_late_video_start foul_committed_penalty foul_won_penalty
# 4                          NaN                    NaN              NaN
# 7                          NaN                    NaN              NaN
# 10                         NaN                    NaN              NaN
# 13                         NaN                    NaN              NaN
# 16                         NaN                    NaN              NaN

# %%
# Criando função para geração dos gráficos de análise
def pass_arrow (jogo, jogador):
    df_filtered_jogo = df_pass[df_pass.match_id == jogo]
    df_filtered_jogador = df_filtered_jogo[df_filtered_jogo.player_name == jogador].reset_index(drop=True)
    
    start_x = df_filtered_jogador.x
    start_y = df_filtered_jogador.y
    end_x = df_filtered_jogador.end_x
    end_y = df_filtered_jogador.end_y
    
    # Condições para "bons passes" (em direção ao gol dentro do intervalo)
    passe_ofensivo = (end_x > start_x + 7)
    passe_lateral = (end_x < start_x + 7) & (end_x > start_x - 7)
    passe_defensivo = (end_x < start_x + 7)
    
    # Definindo cor para tipos de passes
    cores = []
    for i in range(len(start_x)):
        if passe_ofensivo[i]:
            cores.append('#000000')  # Preto para passes ofensivos
        elif passe_lateral[i]:
            cores.append('#0000FF')  # Azul para passes laterais
        elif passe_defensivo[i]:
            cores.append('#FF0000')  # Vermelho para passes defensivos
        else:
            cores.append('#FFA500')  # Laranja para outros passes
    
    
    # Gerando o campo de jogo
    pitch = Pitch(pitch_color='#aabb97', line_color='white', stripe_color='#c2d59d', stripe=True)
    fig, ax = pitch.draw(figsize=(8, 6))
    
    # Plotando as marcações
    for i in range(len(start_x)):
        pitch.lines(start_x[i], start_y[i], end_x[i], end_y[i], ax=ax, color=cores[i], comet=True, transparent=True)
    
    
    plt.show()

# %%
# Extraindo a fração para facilitar a visualização do id do jogo para seleção
df_partidas[df_partidas['match_id'].isin(jogos_ids)][['match_id', 'home_team', 'away_team']]
# Out:
#     match_id home_team    away_team
# 3    3857258    Brazil       Serbia
# 14   3857269    Brazil  Switzerland
# 22   3869420   Croatia       Brazil
# 25   3869253    Brazil  South Korea
# 48   3857280  Cameroon       Brazil

# %%
# Extraindo os nomes completos dos jogadores da equipe selecionada anteriormente
df_jogadores = df_combined[df_combined['team_name'] == equipe]
nomes_jogadores = df_jogadores['player_name'].sort_values().unique()

nomes_jogadores
# Out:
# array(['Alex Nicolao Telles', 'Alex Sandro Lobo Silva',
#        'Alisson Ramsés Becker', 'Antony Matheus dos Santos',
#        'Bruno Guimarães Rodriguez Moura', 'Carlos Henrique Casimiro',
#        'Daniel Alves da Silva', 'Danilo Luiz da Silva',
#        'Ederson Santana de Moraes', 'Frederico Rodrigues Santos',
#        'Fábio Henrique Tavares', 'Gabriel Fernando de Jesus',
#        'Gabriel Teodoro Martinelli Silva',
#        'Gleison Bremer Silva Nascimento',
#        'Lucas Tolentino Coelho de Lima', 'Marcos Aoás Corrêa',
#        'Neymar da Silva Santos Junior',
#        'Pedro Guilherme Abreu dos Santos', 'Raphael Dias Belloli',
#        'Richarlison de Andrade', 'Rodrygo Silva de Goes',
#        'Thiago Emiliano da Silva',
#        'Vinícius José Paixão de Oliveira Júnior',
#        'Weverton Pereira da Silva', 'Éder Gabriel Militão',
#        'Éverton Augusto de Barros Ribeiro', nan], dtype=object)

# %% [markdown]
# ## Analisando

# %%
# Selecionando o jogo e o jogador que desejamos analisar os passes
pass_arrow(3869420, 'Neymar da Silva Santos Junior')
