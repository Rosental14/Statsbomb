# %%
from mplsoccer.pitch import Pitch
from mplsoccer import arrowhead_marker
import numpy as np

# %%
pitch = Pitch(pitch_color='grass', line_color='white', stripe=True)
fig, ax = pitch.draw()

# %%
pitch = Pitch()
fig, ax = pitch.draw()
pitch.arrows(60, 40, 60, 60, ax=ax) # x,y x,y

# %%
pitch = Pitch()
fig, ax = pitch.draw()
pitch.lines(30, 30, 0, 40, comet=True, transparent=True, ax=ax)

# %%
pitch = Pitch()
fig, ax = pitch.draw()
pitch.scatter(30, 30, ax=ax)

# %%
pitch = Pitch()
fig, ax = pitch.draw()
pitch.scatter(30, 30, rotation_degrees=45, marker=arrowhead_marker, ax=ax)

# %%
pitch = Pitch()
fig, ax = pitch.draw()
pitch.scatter(20, 50, marker='football', ax=ax)
# Out:
# (<matplotlib.collections.PathCollection at 0x2b966600dd0>,
#  <matplotlib.collections.PathCollection at 0x2b966600ad0>)

# %%
pitch = Pitch()
fig, ax = pitch.draw()
pitch.goal_angle(100, 30, alpha=0.5, color='red', ax=ax)

# %%
pitch = Pitch(label=True, axis=True)
fig, ax = pitch.draw()
shape1 = np.array([[60, 2], [80, 30], [40, 30], [40, 20]])
shape2 = np.array([[70, 70], [60, 50], [40, 40]])
verts = [shape1, shape2]
pitch.polygon(verts, color='red', alpha=0.3, ax=ax)
# Out:
# [<matplotlib.patches.Polygon at 0x2b962cff560>,
#  <matplotlib.patches.Polygon at 0x2b962cfec90>]
