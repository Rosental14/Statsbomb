# %% [markdown]
# <center>
#
# # Football Analytics

# %% [markdown]
# Neste notebook iremos explorar dados gratuitos disponibilizados pelo StatsBomb.

# %% [markdown]
# ## IMPORTANDO AS BIBLIOTECAS NECESSÁRIAS

# %%
# Importando Bibliotecas necessárias
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import to_rgba
from urllib.request import urlopen
from mplsoccer import Sbopen, Pitch, FontManager, VerticalPitch, add_image
from PIL import Image
from statsbombpy import sb

# %%
# Ajustar as configurações de exibição do pandas
pd.set_option('display.max_columns', None)  # None permite mostrar todas as colunas

# %% [markdown]
# ## EXTRAINDO AS COMPETIÇÕES E TEMPORADAS DISPONÍVEIS

# %%
competitions = sb.competitions()
competitions.head(3)
# Out:
#    competition_id  season_id country_name        competition_name  \
# 0               9        281      Germany           1. Bundesliga
# 1               9         27      Germany           1. Bundesliga
# 2            1267        107       Africa  African Cup of Nations
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                       True
#
#   season_name               match_updated           match_updated_360  \
# 0   2023/2024  2024-07-15T14:15:54.671676  2024-07-15T14:17:00.877356
# 1   2015/2016  2024-05-19T11:11:14.192381                        None
# 2        2023  2024-06-13T07:51:02.452825                        None
#
#           match_available_360             match_available
# 0  2024-07-15T14:17:00.877356  2024-07-15T14:15:54.671676
# 1                        None  2024-05-19T11:11:14.192381
# 2                        None  2024-06-13T07:51:02.452825

# %%
# Criando uma lista com todas competições e seus respectivos ids, ordenadas de forma alfabética
competitions_list = competitions[['competition_name', 'competition_id']].drop_duplicates().reset_index(drop=True)

competitions_list
# Out:
#            competition_name  competition_id
# 0             1. Bundesliga               9
# 1    African Cup of Nations            1267
# 2          Champions League              16
# 3              Copa America             223
# 4              Copa del Rey              87
# 5   FA Women's Super League              37
# 6        FIFA U20 World Cup            1470
# 7            FIFA World Cup              43
# 8       Indian Super league            1238
# 9                   La Liga              11
# 10         Liga Profesional              81
# 11                  Ligue 1               7
# 12      Major League Soccer              44
# 13    North American League             116
# 14                     NWSL              49
# 15           Premier League               2
# 16                  Serie A              12
# 17                UEFA Euro              55
# 18       UEFA Europa League              35
# 19        UEFA Women's Euro              53
# 20        Women's World Cup              72

# %%
# Criando uma lista com todas as temporadas listadas da mais recente para a mais antiga
seasons_list = competitions[['season_name', 'season_id']].sort_values(by='season_name', ascending=False).drop_duplicates().reset_index(drop=True)

seasons_list
# Out:
#    season_name  season_id
# 0         2024        282
# 1    2023/2024        281
# 2         2023        107
# 3    2022/2023        235
# 4         2022        106
# 5    2021/2022        108
# 6    2020/2021         90
# 7         2020         43
# 8    2019/2020         42
# 9         2019         30
# 10   2018/2019          4
# 11        2018          3
# 12   2017/2018          1
# 13   2016/2017          2
# 14   2015/2016         27
# 15   2014/2015         26
# 16   2013/2014         25
# 17   2012/2013         24
# 18   2011/2012         23
# 19   2010/2011         22
# 20   2009/2010         21
# 21   2008/2009         41
# 22   2007/2008         40
# 23   2006/2007         39
# 24   2005/2006         38
# 25   2004/2005         37
# 26   2003/2004         44
# 27   1999/2000         76
# 28   1997/1998         48
# 29        1990         55
# 30   1988/1989         75
# 31   1986/1987         86
# 32        1986         54
# 33   1983/1984         84
# 34   1982/1983        268
# 35        1981        275
# 36        1979        274
# 37   1977/1978        279
# 38        1977         68
# 39        1974         51
# 40   1973/1974        278
# 41   1972/1973        277
# 42   1971/1972         71
# 43   1970/1971        276
# 44        1970        272
# 45        1962        270
# 46        1958        269

# %% [markdown]
# ## SELECIONANDO COMPETIÇÃO E TEMPORADA

# %%
# Altere o id da competição e da temporada conforme desejar observando as listagens acima
campeonato = sb.matches(competition_id=43, season_id=106)
campeonato.head(3)
# Out:
#    match_id  match_date      kick_off                     competition season  \
# 0   3857256  2022-12-02  21:00:00.000  International - FIFA World Cup   2022
# 1   3869151  2022-12-03  21:00:00.000  International - FIFA World Cup   2022
# 2   3857257  2022-11-30  17:00:00.000  International - FIFA World Cup   2022
#
#    home_team    away_team  home_score  away_score match_status  \
# 0     Serbia  Switzerland           2           3    available
# 1  Argentina    Australia           2           1    available
# 2  Australia      Denmark           1           0    available
#
#   match_status_360                last_updated            last_updated_360  \
# 0        available  2023-02-17T23:45:15.306706  2023-04-26T23:49:58.956186
# 1        available  2023-07-30T07:46:05.382784  2023-07-30T07:48:51.865595
# 2        available  2023-04-28T17:13:10.958725  2023-06-20T11:04:37.638969
#
#    match_week competition_stage                stadium  \
# 0           3       Group Stage            Stadium 974
# 1           4       Round of 16  Ahmad bin Ali Stadium
# 2           3       Group Stage   Al Janoub Stadium
#
#                      referee             home_managers        away_managers  \
# 0  Fernando Andrés Rapallini          Dragan Stojković          Murat Yakin
# 1           Szymon Marciniak  Lionel Sebastián Scaloni  Graham James Arnold
# 2           Mustapha Ghorbal       Graham James Arnold      Kasper Hjulmand
#
#   data_version shot_fidelity_version xy_fidelity_version
# 0        1.1.0                     2                   2
# 1        1.1.0                     2                   2
# 2        1.1.0                     2                   2

# %%
# checando a escrita exata de cada equipe
campeonato['home_team'].sort_values().unique()
# Out:
# array(['Argentina', 'Australia', 'Belgium', 'Brazil', 'Cameroon',
#        'Canada', 'Costa Rica', 'Croatia', 'Denmark', 'Ecuador', 'England',
#        'France', 'Germany', 'Ghana', 'Iran', 'Japan', 'Mexico', 'Morocco',
#        'Netherlands', 'Poland', 'Portugal', 'Qatar', 'Saudi Arabia',
#        'Senegal', 'Serbia', 'South Korea', 'Spain', 'Switzerland',
#        'Tunisia', 'United States', 'Uruguay', 'Wales'], dtype=object)

# %% [markdown]
# ## SELECIONANDO EQUIPE

# %%
# Filtrando partidas de uma seleção específica (Selecione a equipe que desejar)

equipe = 'Brazil'
df_partidas = campeonato.loc[(campeonato['home_team'] == f'{equipe}')|(campeonato['away_team'] == f'{equipe}')]
df_partidas.head(3)
# Out:
#     match_id  match_date      kick_off                     competition season  \
# 3    3857258  2022-11-24  21:00:00.000  International - FIFA World Cup   2022
# 14   3857269  2022-11-28  18:00:00.000  International - FIFA World Cup   2022
# 22   3869420  2022-12-09  17:00:00.000  International - FIFA World Cup   2022
#
#    home_team    away_team  home_score  away_score match_status  \
# 3     Brazil       Serbia           2           0    available
# 14    Brazil  Switzerland           1           0    available
# 22   Croatia       Brazil           1           1    available
#
#    match_status_360                last_updated            last_updated_360  \
# 3         available  2023-06-24T17:17:27.911026  2023-07-11T14:56:31.096588
# 14        available  2023-03-28T12:54:30.503171  2023-07-11T15:07:29.255525
# 22        available  2023-04-19T06:28:33.041249  2023-04-26T23:04:13.569501
#
#     match_week competition_stage                  stadium  \
# 3            1       Group Stage           Lusail Stadium
# 14           2       Group Stage              Stadium 974
# 22           5    Quarter-finals  Education City Stadium
#
#                          referee           home_managers  \
# 3                Alireza Faghani   Telê Santana da Silva
# 14  Ivan Arcides Barton Cisneros  Adenor Leonardo Bacchi
# 22                Michael Oliver            Zlatko Dalić
#
#             away_managers data_version shot_fidelity_version  \
# 3        Dragan Stojković        1.1.0                     2
# 14            Murat Yakin        1.1.0                     2
# 22  Telê Santana da Silva        1.1.0                     2
#
#    xy_fidelity_version
# 3                    2
# 14                   2
# 22                   2

# %%
# Extarindo a lista de jogos da equipe selecionada
jogos_ids = df_partidas['match_id'].unique().tolist()
jogos_ids
# Out:
# [3857258, 3857269, 3869420, 3869253, 3857280]

# %%
# Inicializar o parser
parser = Sbopen()

# Listas para armazenar os dataframes
all_df = []
all_related = []
all_freeze = []
all_tactics = []

# Iterar sobre cada ID de jogo e coletar os dados
for jogo in jogos_ids:
    df, related, freeze, tactics = parser.event(jogo)
    
    # Adicionar os dataframes coletados às listas correspondentes
    all_df.append(df)
    all_related.append(related)
    all_freeze.append(freeze)
    all_tactics.append(tactics)

df_combined = pd.concat(all_df, ignore_index=True)
related_combined = pd.concat(all_related, ignore_index=True)
freeze_combined = pd.concat(all_freeze, ignore_index=True)
tactics_combined = pd.concat(all_tactics, ignore_index=True)

# %%
# df contendo todos os jogos da equipe selecionada
df_combined.sample(3)
# Out:
#                                          id  index  period        timestamp  \
# 5666   f05353c4-7ff3-4e1e-9bc9-f4904fc2655f   2011       1  00:45:00.354000
# 9276   73f34e62-bb30-4a4c-81ba-fef4096c438c   1834       1  00:42:15.238000
# 12656  5d89d69a-0a22-4239-86aa-1be085f471b6     69       1  00:01:09.910000
#
#        minute  second  possession  duration  match_id  type_id     type_name  \
# 5666       45       0          82  1.062826   3857269       30          Pass
# 9276       42      15          83  1.231551   3869420       43         Carry
# 12656       1       9           3       NaN   3869253       42  Ball Receipt
#
#        possession_team_id possession_team_name  play_pattern_id  \
# 5666                  773          Switzerland                7
# 9276                  785              Croatia                1
# 12656                 781               Brazil                3
#
#       play_pattern_name  team_id    team_name tactics_formation  player_id  \
# 5666     From Goal Kick      773  Switzerland              None     8814.0
# 9276       Regular Play      785      Croatia              None    29163.0
# 12656    From Free Kick      781       Brazil              None     4320.0
#
#                          player_name  position_id              position_name  \
# 5666                     Nico Elvedi          5.0           Left Center Back
# 9276                 Josip Juranović          2.0                 Right Back
# 12656  Neymar da Silva Santos Junior         19.0  Center Attacking Midfield
#
#        pass_recipient_id pass_recipient_name  pass_length  pass_angle  \
# 5666              3500.0        Granit Xhaka    10.454664    0.382283
# 9276                 NaN                 NaN          NaN         NaN
# 12656                NaN                 NaN          NaN         NaN
#
#        pass_height_id pass_height_name  end_x  end_y  body_part_id  \
# 5666              1.0      Ground Pass   21.8   35.2          38.0
# 9276              NaN              NaN   11.0   74.0           NaN
# 12656             NaN              NaN    NaN    NaN           NaN
#
#       body_part_name  sub_type_id sub_type_name     x     y  under_pressure  \
# 5666       Left Foot          NaN           NaN  12.1  31.3             NaN
# 9276             NaN          NaN           NaN  11.0  74.0             NaN
# 12656            NaN          NaN           NaN  71.6  11.8             NaN
#
#        counterpress  outcome_id outcome_name  out pass_cross pass_switch  \
# 5666            NaN         NaN          NaN  NaN        NaN         NaN
# 9276            NaN         NaN          NaN  NaN        NaN         NaN
# 12656           NaN         9.0   Incomplete  NaN        NaN         NaN
#
#        off_camera  foul_committed_card_id foul_committed_card_name aerial_won  \
# 5666          NaN                     NaN                      NaN        NaN
# 9276          NaN                     NaN                      NaN        NaN
# 12656         NaN                     NaN                      NaN        NaN
#
#       foul_committed_advantage foul_won_advantage foul_won_defensive  \
# 5666                       NaN                NaN                NaN
# 9276                       NaN                NaN                NaN
# 12656                      NaN                NaN                NaN
#
#        technique_id technique_name shot_one_on_one  shot_statsbomb_xg  end_z  \
# 5666            NaN            NaN             NaN                NaN    NaN
# 9276            NaN            NaN             NaN                NaN    NaN
# 12656           NaN            NaN             NaN                NaN    NaN
#
#        goalkeeper_position_id goalkeeper_position_name  \
# 5666                      NaN                      NaN
# 9276                      NaN                      NaN
# 12656                     NaN                      NaN
#
#       injury_stoppage_in_chain pass_assisted_shot_id pass_shot_assist  \
# 5666                       NaN                   NaN              NaN
# 9276                       NaN                   NaN              NaN
# 12656                      NaN                   NaN              NaN
#
#       shot_key_pass_id dribble_nutmeg ball_recovery_recovery_failure  \
# 5666               NaN            NaN                            NaN
# 9276               NaN            NaN                            NaN
# 12656              NaN            NaN                            NaN
#
#       dribble_overrun ball_recovery_offensive shot_first_time block_offensive  \
# 5666              NaN                     NaN             NaN             NaN
# 9276              NaN                     NaN             NaN             NaN
# 12656             NaN                     NaN             NaN             NaN
#
#        substitution_replacement_id substitution_replacement_name  \
# 5666                           NaN                           NaN
# 9276                           NaN                           NaN
# 12656                          NaN                           NaN
#
#        bad_behaviour_card_id bad_behaviour_card_name pass_goal_assist  \
# 5666                     NaN                     NaN              NaN
# 9276                     NaN                     NaN              NaN
# 12656                    NaN                     NaN              NaN
#
#       pass_cut_back block_deflection shot_deflected dribble_no_touch  \
# 5666            NaN              NaN            NaN              NaN
# 9276            NaN              NaN            NaN              NaN
# 12656           NaN              NaN            NaN              NaN
#
#       foul_committed_offensive pass_miscommunication pass_deflected  \
# 5666                       NaN                   NaN            NaN
# 9276                       NaN                   NaN            NaN
# 12656                      NaN                   NaN            NaN
#
#       pass_no_touch half_start_late_video_start foul_committed_penalty  \
# 5666            NaN                         NaN                    NaN
# 9276            NaN                         NaN                    NaN
# 12656           NaN                         NaN                    NaN
#
#       foul_won_penalty
# 5666               NaN
# 9276               NaN
# 12656              NaN

# %%
# Extraindo os nomes completos dos jogadores da equipe selecionada anteriormente
df_jogadores = df_combined[df_combined['team_name'] == equipe]
nomes_jogadores = df_jogadores['player_name'].sort_values().unique()

nomes_jogadores
# Out:
# array(['Alex Nicolao Telles', 'Alex Sandro Lobo Silva',
#        'Alisson Ramsés Becker', 'Antony Matheus dos Santos',
#        'Bruno Guimarães Rodriguez Moura', 'Carlos Henrique Casimiro',
#        'Daniel Alves da Silva', 'Danilo Luiz da Silva',
#        'Ederson Santana de Moraes', 'Frederico Rodrigues Santos',
#        'Fábio Henrique Tavares', 'Gabriel Fernando de Jesus',
#        'Gabriel Teodoro Martinelli Silva',
#        'Gleison Bremer Silva Nascimento',
#        'Lucas Tolentino Coelho de Lima', 'Marcos Aoás Corrêa',
#        'Neymar da Silva Santos Junior',
#        'Pedro Guilherme Abreu dos Santos', 'Raphael Dias Belloli',
#        'Richarlison de Andrade', 'Rodrygo Silva de Goes',
#        'Thiago Emiliano da Silva',
#        'Vinícius José Paixão de Oliveira Júnior',
#        'Weverton Pereira da Silva', 'Éder Gabriel Militão',
#        'Éverton Augusto de Barros Ribeiro', nan], dtype=object)

# %%
# Extraindo os nomes das ações que podem ser analisadas
df_combined['type_name'].sort_values().unique()
# Out:
# array(['50/50', 'Bad Behaviour', 'Ball Receipt', 'Ball Recovery', 'Block',
#        'Carry', 'Clearance', 'Dispossessed', 'Dribble', 'Dribbled Past',
#        'Duel', 'Error', 'Foul Committed', 'Foul Won', 'Goal Keeper',
#        'Half End', 'Half Start', 'Injury Stoppage', 'Interception',
#        'Miscontrol', 'Offside', 'Pass', 'Player Off', 'Player On',
#        'Pressure', 'Referee Ball-Drop', 'Shield', 'Shot', 'Starting XI',
#        'Substitution', 'Tactical Shift'], dtype=object)

# %%
# Criando função para geração dos gráficos de análise
def analise (jogador, metrica):
    df_filtered_jogador = df_combined[df_combined.player_name == jogador]
    pontos = df_filtered_jogador[df_filtered_jogador.type_name == metrica].copy()
    print(len(pontos))

    # Gerando o gráfico no campo de jogo
    pitch = Pitch(pitch_color='#aabb97', line_color='white',
              stripe_color='#c2d59d', stripe=True)

    fig, ax = pitch.draw(figsize=(8, 6))
    #hull = pitch.convexhull(pontos.x, pontos.y)
    #poly = pitch.polygon(hull, ax=ax, edgecolor='cornflowerblue', facecolor='cornflowerblue', alpha=0.3)
    scatter = pitch.scatter(pontos.x, pontos.y, ax=ax, edgecolor='black', facecolor='cornflowerblue')
    plt.show()

# %% [markdown]
# ## Analisando

# %% [markdown]
# **Atenção:** Nem todos os parâmetros geram pontos para impressão no gráfico, utilize com :
#
# Ball Receipt, Ball Recovery, Block, Clearance, Dispossessed, Dribble, Dribbled Past, Duel, Error, Foul Committed, Foul Won, Interception, Miscontrol, Offside, Pass, Pressure, Shield e Shot

# %%
# Selecionando o jogador e a métrica que desejamos analisar (substitua conforme necessidade, lembrando que as escritas devem ser idênticas)
analise('Neymar da Silva Santos Junior', 'Pass')
# Out:
# 156

# %%
related_combined
# Out:
#        match_id                                    id  index     type_name  \
# 0       3857258  f9296299-3395-4a1b-9349-4d740e0eab95      3    Half Start
# 1       3857258  0c646c2e-85f5-4cee-b4cd-aa903ba752b2      4    Half Start
# 2       3857258  dd455069-07ce-4acb-a490-81118fcb0235      5          Pass
# 3       3857258  632321bc-ef74-4b84-8919-5b5b8ecafa05      6  Ball Receipt
# 4       3857258  bd74159d-a009-4ffb-bf61-e5755adf3d5f      7         Carry
# ...         ...                                   ...    ...           ...
# 37369   3857280  dcfd1fe4-22dd-47fb-8e20-7710916e37b4   3276  Ball Receipt
# 37370   3857280  7a142f63-4d57-4e1b-a161-a411fd4c289d   3293          Pass
# 37371   3857280  d79d1f3b-a40d-481a-b93a-7cba0a9c92f1   3291  Ball Receipt
# 37372   3857280  4464c4a3-e0f3-448a-a046-6fd431a41d40   3294  Ball Receipt
# 37373   3857280  b0be9a75-282c-42fe-97bd-08b8a1723103   3296          Pass
#
#                                  id_related  index_related type_name_related
# 0      0c646c2e-85f5-4cee-b4cd-aa903ba752b2              4        Half Start
# 1      f9296299-3395-4a1b-9349-4d740e0eab95              3        Half Start
# 2      632321bc-ef74-4b84-8919-5b5b8ecafa05              6      Ball Receipt
# 3      dd455069-07ce-4acb-a490-81118fcb0235              5              Pass
# 4      3ec348c7-e144-4c2a-8ad0-5c6e18199403              8              Pass
# ...                                     ...            ...               ...
# 37369  92752f10-fc2b-454c-a0d4-1ea9238a68bd           3277             Carry
# 37370  3b379029-5ea2-48fc-89d4-a01ac604c15b           3292             Carry
# 37371  3b379029-5ea2-48fc-89d4-a01ac604c15b           3292             Carry
# 37372  880873fd-b476-41dd-82d3-98f0a4e6fb0c           3295             Carry
# 37373  880873fd-b476-41dd-82d3-98f0a4e6fb0c           3295             Carry
#
# [37374 rows x 7 columns]

# %%
freeze_combined.head()
# Out:
#    teammate  match_id                                    id      x     y  \
# 0     False   3857258  7e920dff-ac95-416c-afd5-aa517b812da3  111.0  42.1
# 1     False   3857258  7e920dff-ac95-416c-afd5-aa517b812da3  117.3  33.6
# 2     False   3857258  7e920dff-ac95-416c-afd5-aa517b812da3  114.6  34.8
# 3     False   3857258  7e920dff-ac95-416c-afd5-aa517b812da3  118.0  36.3
# 4     False   3857258  7e920dff-ac95-416c-afd5-aa517b812da3  115.4  43.3
#
#    player_id              player_name  position_id             position_name  \
# 0       6687               Saša Lukić            9  Right Defensive Midfield
# 1       7993         Filip Mladenović            8            Left Wing Back
# 2       5589  Sergej Milinković-Savić           20   Left Attacking Midfield
# 3       4269      Aleksandar Mitrović           23            Center Forward
# 4       6321          Milos Veljkovic            4               Center Back
#
#    event_freeze_id
# 0                1
# 1                2
# 2                3
# 3                4
# 4                5

# %%
# Gerando o gráfico no campo de jogo
fui = freeze_combined[freeze_combined['event_freeze_id'] == 3]

pitch = Pitch(pitch_color='#aabb97', line_color='white',
              stripe_color='#c2d59d', stripe=True)

fig, ax = pitch.draw(figsize=(10, 7.5))
hull = pitch.convexhull(fui.x, fui.y)
poly = pitch.polygon(hull, ax=ax, edgecolor='cornflowerblue', facecolor='cornflowerblue', alpha=0.3)
scatter = pitch.scatter(fui.x, fui.y, ax=ax, edgecolor='black', facecolor='cornflowerblue')
plt.show()

# %%
tactics_combined
# Out:
#      jersey_number  match_id                                    id  player_id  \
# 0                1   3857258  d8786232-319f-4825-ac63-d84ae55b5417       5547
# 1                2   3857258  d8786232-319f-4825-ac63-d84ae55b5417       3063
# 2                4   3857258  d8786232-319f-4825-ac63-d84ae55b5417       4372
# 3                3   3857258  d8786232-319f-4825-ac63-d84ae55b5417       3295
# 4                6   3857258  d8786232-319f-4825-ac63-d84ae55b5417       6945
# ..             ...       ...                                   ...        ...
# 270              8   3857280  bd3092b5-6413-4133-aea4-0457d3d365c6       3141
# 271              6   3857280  bd3092b5-6413-4133-aea4-0457d3d365c6      16015
# 272             12   3857280  bd3092b5-6413-4133-aea4-0457d3d365c6       3551
# 273             10   3857280  bd3092b5-6413-4133-aea4-0457d3d365c6      11174
# 274             13   3857280  bd3092b5-6413-4133-aea4-0457d3d365c6       3499
#
#                        player_name  position_id            position_name  \
# 0            Alisson Ramsés Becker            1               Goalkeeper
# 1             Danilo Luiz da Silva            2               Right Back
# 2               Marcos Aoás Corrêa            3        Right Center Back
# 3         Thiago Emiliano da Silva            5         Left Center Back
# 4           Alex Sandro Lobo Silva            6                Left Back
# ..                             ...          ...                      ...
# 270     André-Frank Zambo Anguissa           11  Left Defensive Midfield
# 271         Nicolas Moumi Ngamaleu           12           Right Midfield
# 272      Karl Brillant Toko Ekambi           16            Left Midfield
# 273         Vincent Paté Aboubakar           22     Right Center Forward
# 274  Jean-Eric Maxim Choupo-Moting           24      Left Center Forward
#
#      event_tactics_id
# 0                   1
# 1                   2
# 2                   3
# 3                   4
# 4                   5
# ..                ...
# 270                 7
# 271                 8
# 272                 9
# 273                10
# 274                11
#
# [275 rows x 8 columns]
