# %% [markdown]
# <center>
#
# # Football Analytics

# %% [markdown]
# Neste notebook iremos explorar dados gratuitos disponibilizados pelo StatsBomb.

# %% [markdown]
# ## IMPORTANDO AS BIBLIOTECAS NECESSÁRIAS

# %%
# Importando Bibliotecas necessárias
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import to_rgba
from urllib.request import urlopen
from mplsoccer import Sbopen, Pitch, FontManager, VerticalPitch, add_image
from PIL import Image
from statsbombpy import sb

# %%
# Ajustar as configurações de exibição do pandas
pd.set_option('display.max_columns', None)  # None permite mostrar todas as colunas

# %% [markdown]
# ## EXTRAINDO AS COMPETIÇÕES E TEMPORADAS DISPONÍVEIS

# %%
competitions = sb.competitions()
competitions.head(3)
# Out:
#    competition_id  season_id country_name        competition_name  \
# 0               9        281      Germany           1. Bundesliga
# 1               9         27      Germany           1. Bundesliga
# 2            1267        107       Africa  African Cup of Nations
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                       True
#
#   season_name               match_updated           match_updated_360  \
# 0   2023/2024  2024-07-15T14:15:54.671676  2024-07-15T14:17:00.877356
# 1   2015/2016  2024-05-19T11:11:14.192381                        None
# 2        2023  2024-06-13T07:51:02.452825                        None
#
#           match_available_360             match_available
# 0  2024-07-15T14:17:00.877356  2024-07-15T14:15:54.671676
# 1                        None  2024-05-19T11:11:14.192381
# 2                        None  2024-06-13T07:51:02.452825

# %%
# Criando uma lista com todas competições e seus respectivos ids, ordenadas de forma alfabética
competitions_list = competitions[['competition_name', 'competition_id']].drop_duplicates().reset_index(drop=True)

competitions_list
# Out:
#            competition_name  competition_id
# 0             1. Bundesliga               9
# 1    African Cup of Nations            1267
# 2          Champions League              16
# 3              Copa America             223
# 4              Copa del Rey              87
# 5   FA Women's Super League              37
# 6        FIFA U20 World Cup            1470
# 7            FIFA World Cup              43
# 8       Indian Super league            1238
# 9                   La Liga              11
# 10         Liga Profesional              81
# 11                  Ligue 1               7
# 12      Major League Soccer              44
# 13    North American League             116
# 14                     NWSL              49
# 15           Premier League               2
# 16                  Serie A              12
# 17                UEFA Euro              55
# 18       UEFA Europa League              35
# 19        UEFA Women's Euro              53
# 20        Women's World Cup              72

# %%
# Criando uma lista com todas as temporadas listadas da mais recente para a mais antiga
seasons_list = competitions[['season_name', 'season_id']].sort_values(by='season_name', ascending=False).drop_duplicates().reset_index(drop=True)

seasons_list
# Out:
#    season_name  season_id
# 0         2024        282
# 1    2023/2024        281
# 2         2023        107
# 3    2022/2023        235
# 4         2022        106
# 5    2021/2022        108
# 6    2020/2021         90
# 7         2020         43
# 8    2019/2020         42
# 9         2019         30
# 10   2018/2019          4
# 11        2018          3
# 12   2017/2018          1
# 13   2016/2017          2
# 14   2015/2016         27
# 15   2014/2015         26
# 16   2013/2014         25
# 17   2012/2013         24
# 18   2011/2012         23
# 19   2010/2011         22
# 20   2009/2010         21
# 21   2008/2009         41
# 22   2007/2008         40
# 23   2006/2007         39
# 24   2005/2006         38
# 25   2004/2005         37
# 26   2003/2004         44
# 27   1999/2000         76
# 28   1997/1998         48
# 29        1990         55
# 30   1988/1989         75
# 31   1986/1987         86
# 32        1986         54
# 33   1983/1984         84
# 34   1982/1983        268
# 35        1981        275
# 36        1979        274
# 37   1977/1978        279
# 38        1977         68
# 39        1974         51
# 40   1973/1974        278
# 41   1972/1973        277
# 42   1971/1972         71
# 43   1970/1971        276
# 44        1970        272
# 45        1962        270
# 46        1958        269

# %% [markdown]
# ## SELECIONANDO COMPETIÇÃO E TEMPORADA

# %%
# Altere o id da competição e da temporada conforme desejar observando as listagens acima
campeonato = sb.matches(competition_id=43, season_id=106)
campeonato.head(3)
# Out:
#    match_id  match_date      kick_off                     competition season  \
# 0   3857256  2022-12-02  21:00:00.000  International - FIFA World Cup   2022
# 1   3869151  2022-12-03  21:00:00.000  International - FIFA World Cup   2022
# 2   3857257  2022-11-30  17:00:00.000  International - FIFA World Cup   2022
#
#    home_team    away_team  home_score  away_score match_status  \
# 0     Serbia  Switzerland           2           3    available
# 1  Argentina    Australia           2           1    available
# 2  Australia      Denmark           1           0    available
#
#   match_status_360                last_updated            last_updated_360  \
# 0        available  2023-02-17T23:45:15.306706  2023-04-26T23:49:58.956186
# 1        available  2023-07-30T07:46:05.382784  2023-07-30T07:48:51.865595
# 2        available  2023-04-28T17:13:10.958725  2023-06-20T11:04:37.638969
#
#    match_week competition_stage                stadium  \
# 0           3       Group Stage            Stadium 974
# 1           4       Round of 16  Ahmad bin Ali Stadium
# 2           3       Group Stage   Al Janoub Stadium
#
#                      referee             home_managers        away_managers  \
# 0  Fernando Andrés Rapallini          Dragan Stojković          Murat Yakin
# 1           Szymon Marciniak  Lionel Sebastián Scaloni  Graham James Arnold
# 2           Mustapha Ghorbal       Graham James Arnold      Kasper Hjulmand
#
#   data_version shot_fidelity_version xy_fidelity_version
# 0        1.1.0                     2                   2
# 1        1.1.0                     2                   2
# 2        1.1.0                     2                   2

# %%
# checando a escrita exata de cada equipe
campeonato['home_team'].sort_values().unique()
# Out:
# array(['Argentina', 'Australia', 'Belgium', 'Brazil', 'Cameroon',
#        'Canada', 'Costa Rica', 'Croatia', 'Denmark', 'Ecuador', 'England',
#        'France', 'Germany', 'Ghana', 'Iran', 'Japan', 'Mexico', 'Morocco',
#        'Netherlands', 'Poland', 'Portugal', 'Qatar', 'Saudi Arabia',
#        'Senegal', 'Serbia', 'South Korea', 'Spain', 'Switzerland',
#        'Tunisia', 'United States', 'Uruguay', 'Wales'], dtype=object)

# %% [markdown]
# ## SELECIONANDO EQUIPE

# %%
# Filtrando partidas de uma seleção específica (Selecione a equipe que desejar)

equipe = 'Croatia'
df_partidas = campeonato.loc[(campeonato['home_team'] == f'{equipe}')|(campeonato['away_team'] == f'{equipe}')]
df_partidas.head(3)
# Out:
#     match_id  match_date      kick_off                     competition season  \
# 18   3869684  2022-12-17  17:00:00.000  International - FIFA World Cup   2022
# 19   3869519  2022-12-13  21:00:00.000  International - FIFA World Cup   2022
# 22   3869420  2022-12-09  17:00:00.000  International - FIFA World Cup   2022
#
#     home_team away_team  home_score  away_score match_status match_status_360  \
# 18    Croatia   Morocco           2           1    available        available
# 19  Argentina   Croatia           3           0    available        available
# 22    Croatia    Brazil           1           1    available        available
#
#                   last_updated            last_updated_360  match_week  \
# 18  2023-02-20T08:56:30.908564  2023-04-26T22:18:59.308194           7
# 19  2023-04-19T06:53:52.197711  2023-04-26T22:32:37.808359           6
# 22  2023-04-19T06:28:33.041249  2023-04-26T23:04:13.569501           5
#
#    competition_stage                               stadium  \
# 18   3rd Place Final  Sheikh Khalifa International Stadium
# 19       Semi-finals                        Lusail Stadium
# 22    Quarter-finals               Education City Stadium
#
#                           referee             home_managers  \
# 18  Abdulrahman Ibrahim Al Jassim              Zlatko Dalić
# 19                 Daniele Orsato  Lionel Sebastián Scaloni
# 22                 Michael Oliver              Zlatko Dalić
#
#             away_managers data_version shot_fidelity_version  \
# 18        Hoalid Regragui        1.1.0                     2
# 19           Zlatko Dalić        1.1.0                     2
# 22  Telê Santana da Silva        1.1.0                     2
#
#    xy_fidelity_version
# 18                   2
# 19                   2
# 22                   2

# %%
# Extarindo a lista de jogos da equipe selecionada
jogos_ids = df_partidas['match_id'].unique().tolist()
jogos_ids
# Out:
# [3869684, 3869519, 3869420, 3869219, 3857296, 3857281, 3857277]

# %%
# Inicializar o parser
parser = Sbopen()

# Listas para armazenar os dataframes
all_df = []
all_related = []
all_freeze = []
all_tactics = []

# Iterar sobre cada ID de jogo e coletar os dados
for jogo in jogos_ids:
    df, related, freeze, tactics = parser.event(jogo)
    
    # Adicionar os dataframes coletados às listas correspondentes
    all_df.append(df)
    all_related.append(related)
    all_freeze.append(freeze)
    all_tactics.append(tactics)

df_combined = pd.concat(all_df, ignore_index=True)
related_combined = pd.concat(all_related, ignore_index=True)
freeze_combined = pd.concat(all_freeze, ignore_index=True)
tactics_combined = pd.concat(all_tactics, ignore_index=True)

# %%
# df contendo todos os jogos da equipe selecionada
df_combined.sample(3)
# Out:
#                                         id  index  period        timestamp  \
# 1225  06b144f1-0900-4f08-9941-ea0e5b62ed0b   1226       1  00:32:07.221000
# 9575  0271e907-1b7e-4be0-b4f9-e093bf554838   2210       2  00:07:33.049000
# 379   db9b74ed-12e9-4a64-9d35-9034bfde6e8b    380       1  00:11:27.022000
#
#       minute  second  possession  duration  match_id  type_id     type_name  \
# 1225      32       7          56  0.616173   3869684       30          Pass
# 9575      52      33         109  0.755580   3869420       43         Carry
# 379       11      27          16       NaN   3869684       42  Ball Receipt
#
#       possession_team_id possession_team_name  play_pattern_id  \
# 1225                 788              Morocco                1
# 9575                 781               Brazil                4
# 379                  788              Morocco                4
#
#      play_pattern_name  team_id team_name tactics_formation  player_id  \
# 1225      Regular Play      788   Morocco              None     3625.0
# 9575     From Throw In      781    Brazil              None     3295.0
# 379      From Throw In      788   Morocco              None     7459.0
#
#                    player_name  position_id      position_name  \
# 1225            Sofiane Boufal         21.0          Left Wing
# 9575  Thiago Emiliano da Silva          3.0  Right Center Back
# 379             Jawad El Yamiq          3.0  Right Center Back
#
#       pass_recipient_id pass_recipient_name  pass_length  pass_angle  \
# 1225           156734.0   Bilal El Khannous     9.425497    1.872415
# 9575                NaN                 NaN          NaN         NaN
# 379                 NaN                 NaN          NaN         NaN
#
#       pass_height_id pass_height_name  end_x  end_y  body_part_id  \
# 1225             1.0      Ground Pass   98.2   25.2          40.0
# 9575             NaN              NaN   53.4   40.6           NaN
# 379              NaN              NaN    NaN    NaN           NaN
#
#      body_part_name  sub_type_id sub_type_name      x     y  outcome_id  \
# 1225     Right Foot          NaN           NaN  101.0  16.2         NaN
# 9575            NaN          NaN           NaN   53.2  40.3         NaN
# 379             NaN          NaN           NaN   39.4  70.3         NaN
#
#      outcome_name  under_pressure  out aerial_won  \
# 1225          NaN             NaN  NaN        NaN
# 9575          NaN             NaN  NaN        NaN
# 379           NaN             NaN  NaN        NaN
#
#      ball_recovery_recovery_failure pass_cross  counterpress  technique_id  \
# 1225                            NaN        NaN           NaN           NaN
# 9575                            NaN        NaN           NaN           NaN
# 379                             NaN        NaN           NaN           NaN
#
#      technique_name foul_won_defensive  off_camera pass_switch  \
# 1225            NaN                NaN         NaN         NaN
# 9575            NaN                NaN         NaN         NaN
# 379             NaN                NaN         NaN         NaN
#
#      pass_assisted_shot_id pass_goal_assist  shot_statsbomb_xg  end_z  \
# 1225                   NaN              NaN                NaN    NaN
# 9575                   NaN              NaN                NaN    NaN
# 379                    NaN              NaN                NaN    NaN
#
#      shot_key_pass_id  goalkeeper_position_id goalkeeper_position_name  \
# 1225              NaN                     NaN                      NaN
# 9575              NaN                     NaN                      NaN
# 379               NaN                     NaN                      NaN
#
#      shot_one_on_one pass_shot_assist shot_first_time pass_no_touch  \
# 1225             NaN              NaN             NaN           NaN
# 9575             NaN              NaN             NaN           NaN
# 379              NaN              NaN             NaN           NaN
#
#      block_offensive foul_committed_advantage foul_won_advantage  \
# 1225             NaN                      NaN                NaN
# 9575             NaN                      NaN                NaN
# 379              NaN                      NaN                NaN
#
#      dribble_nutmeg dribble_overrun injury_stoppage_in_chain  \
# 1225            NaN             NaN                      NaN
# 9575            NaN             NaN                      NaN
# 379             NaN             NaN                      NaN
#
#       substitution_replacement_id substitution_replacement_name  \
# 1225                          NaN                           NaN
# 9575                          NaN                           NaN
# 379                           NaN                           NaN
#
#      pass_deflected  bad_behaviour_card_id bad_behaviour_card_name  \
# 1225            NaN                    NaN                     NaN
# 9575            NaN                    NaN                     NaN
# 379             NaN                    NaN                     NaN
#
#       foul_committed_card_id foul_committed_card_name foul_committed_penalty  \
# 1225                     NaN                      NaN                    NaN
# 9575                     NaN                      NaN                    NaN
# 379                      NaN                      NaN                    NaN
#
#      foul_won_penalty ball_recovery_offensive pass_cut_back  \
# 1225              NaN                     NaN           NaN
# 9575              NaN                     NaN           NaN
# 379               NaN                     NaN           NaN
#
#      pass_miscommunication foul_committed_offensive shot_deflected  \
# 1225                   NaN                      NaN            NaN
# 9575                   NaN                      NaN            NaN
# 379                    NaN                      NaN            NaN
#
#      block_deflection half_start_late_video_start dribble_no_touch  \
# 1225              NaN                         NaN              NaN
# 9575              NaN                         NaN              NaN
# 379               NaN                         NaN              NaN
#
#      shot_redirect block_save_block
# 1225           NaN              NaN
# 9575           NaN              NaN
# 379            NaN              NaN

# %%
# Extraindo os nomes das ações que podem ser analisadas
df_combined['type_name'].sort_values().unique()
# Out:
# array(['50/50', 'Bad Behaviour', 'Ball Receipt', 'Ball Recovery', 'Block',
#        'Carry', 'Clearance', 'Dispossessed', 'Dribble', 'Dribbled Past',
#        'Duel', 'Error', 'Foul Committed', 'Foul Won', 'Goal Keeper',
#        'Half End', 'Half Start', 'Injury Stoppage', 'Interception',
#        'Miscontrol', 'Offside', 'Pass', 'Player Off', 'Player On',
#        'Pressure', 'Referee Ball-Drop', 'Shield', 'Shot', 'Starting XI',
#        'Substitution', 'Tactical Shift'], dtype=object)

# %%
# Criando função para geração dos gráficos de análise
def analise (metrica):
    df_filtered_team = df_combined[df_combined.team_name == equipe]
    pontos = df_filtered_team[df_filtered_team.type_name == metrica].copy()
    print(len(pontos))

    # Gerando o gráfico no campo de jogo
    pitch = Pitch(pitch_color='#aabb97', line_color='white',
              stripe_color='#c2d59d', stripe=True)

    fig, ax = pitch.draw(figsize=(8, 6))
    #hull = pitch.convexhull(pontos.x, pontos.y)
    #poly = pitch.polygon(hull, ax=ax, edgecolor='cornflowerblue', facecolor='cornflowerblue', alpha=0.3)
    scatter = pitch.scatter(pontos.x, pontos.y, ax=ax, edgecolor='black', facecolor='cornflowerblue')
    plt.show()

# %% [markdown]
# ## Analisando

# %% [markdown]
# **Atenção:** Nem todos os parâmetros geram pontos para impressão no gráfico, utilize com :
#
# Ball Receipt, Ball Recovery, Block, Clearance, Dispossessed, Dribble, Dribbled Past, Duel, Error, Foul Committed, Foul Won, Interception, Miscontrol, Offside, Pass, Pressure, Shield e Shot

# %%
# Selecionando o jogo, a equipe e a métrica que desejamos analisar (substitua conforme necessidade, lembrando que as escritas devem ser idênticas)
analise('Foul Committed')
# Out:
# 101

# %% [markdown]
# # Fouls committed in each third

# %%
print(equipe)

df_filtered_team = df_combined[df_combined.team_name == equipe]
df_foul_commited = df_filtered_team[df_filtered_team.type_name == 'Foul Committed' ]
print('total de faltas:', len(df_foul_commited))

    # Gerando o gráfico no campo de jogo
pitch = Pitch(pitch_color='#aabb97', line_color='white', stripe_color='#c2d59d', stripe=True)

first_third_fouls = df_foul_commited[df_foul_commited['x'] <= 40]
second_third_fouls = df_foul_commited[(df_foul_commited['x'] > 40) & (df_foul_commited['x'] <= 80)]
third_third = df_foul_commited[df_foul_commited['x'] > 80 ]

print('faltas no primeiro terço:', len(first_third_fouls))
print('faltas no segundo terço:', len(second_third_fouls))
print('faltas no terceiro terço:', len(third_third))

# Definindo as cores com base no terço do campo
cores = []
for _, row in df_foul_commited.iterrows():
    if row['x'] <= 40:
        cores.append('#FF0000')  # Vermelho para o primeiro terço (defensivo)
    elif 40 < row['x'] <= 80:
        cores.append('#0000FF')  # Azul para o segundo terço (meio-campo)
    else:
        cores.append('#000000')  # Preto para o último terço (ofensivo)


fig, ax = pitch.draw(figsize=(8, 6))
#hull = pitch.convexhull(pontos.x, pontos.y)
#poly = pitch.polygon(hull, ax=ax, edgecolor='cornflowerblue', facecolor='cornflowerblue', alpha=0.3)
scatter = pitch.scatter(df_foul_commited.x, df_foul_commited.y, ax=ax, edgecolor='black', color=cores)
plt.show()
# Out:
# Croatia
# total de faltas: 101
# faltas no primeiro terço: 21
# faltas no segundo terço: 43
# faltas no terceiro terço: 37
